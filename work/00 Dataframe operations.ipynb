# %% [markdown]
# # DataFrame Operations

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.types import*

spark = SparkSession.builder.appName('00a DataFrame Operations').getOrCreate()
sc = spark.sparkContext
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/spark-3.2.0-bin-hadoop3.2/jars/spark-unsafe_2.12-3.2.0.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/02/13 10:25:41 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Read a CSV into a dataframe, inferring the schema.
dataPath = "../data/Open_Parking_and_Camera_Violations_100.csv"
fines = spark.read.format("csv")\
  .option("header","true")\
  .option("inferSchema", "true")\
  .load(dataPath)
  
# inferSchema means we will automatically figure out column types 
# at a cost of reading the data more than once

# %%
fines.printSchema()
# Out:
# root
#  |-- Plate: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- License Type: string (nullable = true)
#  |-- Summons Number: long (nullable = true)
#  |-- Issue Date: string (nullable = true)
#  |-- Violation Time: string (nullable = true)
#  |-- Violation: string (nullable = true)
#  |-- Judgment Entry Date: string (nullable = true)
#  |-- Fine Amount: double (nullable = true)
#  |-- Penalty Amount: double (nullable = true)
#  |-- Interest Amount: double (nullable = true)
#  |-- Reduction Amount: double (nullable = true)
#  |-- Payment Amount: double (nullable = true)
#  |-- Amount Due: double (nullable = true)
#  |-- Precinct: integer (nullable = true)
#  |-- County: string (nullable = true)
#  |-- Issuing Agency: string (nullable = true)
#  |-- Violation Status: string (nullable = true)
#  |-- Summons Image: string (nullable = true)

# %%
# A schema is a StructType made up of a number of fields, StructFields, that have a name, type, and a Boolean flag which specifies whether that column can contain missing or null values.
fines.schema
# Out:
# StructType(List(StructField(Plate,StringType,true),StructField(State,StringType,true),StructField(License Type,StringType,true),StructField(Summons Number,LongType,true),StructField(Issue Date,StringType,true),StructField(Violation Time,StringType,true),StructField(Violation,StringType,true),StructField(Judgment Entry Date,StringType,true),StructField(Fine Amount,DoubleType,true),StructField(Penalty Amount,DoubleType,true),StructField(Interest Amount,DoubleType,true),StructField(Reduction Amount,DoubleType,true),StructField(Payment Amount,DoubleType,true),StructField(Amount Due,DoubleType,true),StructField(Precinct,IntegerType,true),StructField(County,StringType,true),StructField(Issuing Agency,StringType,true),StructField(Violation Status,StringType,true),StructField(Summons Image,StringType,true)))

# %%
fines.show(2)
# Out:
# +-------+-----+------------+--------------+----------+--------------+----------------+-------------------+-----------+--------------+---------------+----------------+--------------+----------+--------+------+-----------------+----------------+--------------------+
# |  Plate|State|License Type|Summons Number|Issue Date|Violation Time|       Violation|Judgment Entry Date|Fine Amount|Penalty Amount|Interest Amount|Reduction Amount|Payment Amount|Amount Due|Precinct|County|   Issuing Agency|Violation Status|       Summons Image|
# +-------+-----+------------+--------------+----------+--------------+----------------+-------------------+-----------+--------------+---------------+----------------+--------------+----------+--------+------+-----------------+----------------+--------------------+
# |1994439|   ME|         PAS|    1438400834|06/05/2018|        07:58A|DETACHED TRAILER|               null|       45.0|          10.0|            0.0|             0.0|           0.0|      55.0|      94|     K|POLICE DEPARTMENT| HEARING PENDING|View Summons (htt...|
# |GJK1149|   NY|         PAS|    8836261050|09/14/2020|        04:34P|       CROSSWALK|               null|      115.0|           0.0|            0.0|             0.0|         115.0|       0.0|      46|    BX|          TRAFFIC|            null|View Summons (htt...|
# +-------+-----+------------+--------------+----------+--------------+----------------+-------------------+-----------+--------------+---------------+----------------+--------------+----------+--------+------+-----------------+----------------+--------------------+
# only showing top 2 rows

# %%
fines.select(['Plate', 'Violation']).show(5)
# Out:
# +-------+--------------------+
# |  Plate|           Violation|
# +-------+--------------------+
# |1994439|    DETACHED TRAILER|
# |GJK1149|           CROSSWALK|
# |HXP4226|REG. STICKER-EXPI...|
# |1742308|    DETACHED TRAILER|
# | RR2L42|NO STANDING-DAY/T...|
# +-------+--------------------+
# only showing top 5 rows

# %% [markdown]
# Let's see how to manually specify a known schema for a data file, so we can skip the costly "Infer Schema":

# %%
from pyspark.sql.types import StructField, StructType, StringType, DoubleType, IntegerType

schema = StructType([StructField('Plate',StringType(), True),
                     StructField('State',StringType(),True),
                     StructField('License Type',StringType()),
                     StructField('Summons Number',IntegerType()),
                     StructField('Issue Date',StringType()),
                     StructField('Violation Time',StringType()),
                     StructField('Violation',StringType()),
                     StructField('Judgment Entry Date',StringType()),
                     StructField('Fine Amount',DoubleType(),True),
                     StructField('Penalty Amount',DoubleType(),True),
                     StructField('Interest Amount',DoubleType(),True),
                     StructField('Reduction Amount',DoubleType(),True),
                     StructField('Payment Amount',DoubleType(),True),
                     StructField('Amount Due',DoubleType(),True),
                     StructField('Precinct',IntegerType(),True),
                     StructField('County',StringType(),True),
                     StructField('Issuing Agency',StringType(),True),
                     StructField('Violation Status',StringType(),True),
                     StructField('Summons Image',StringType(),True)])


fine2 = spark.read.format("csv")\
  .option("header","true")\
  .schema(schema)\
  .load(dataPath)

fine2.printSchema()
#fine2.show(5)
# Out:
# root
#  |-- Plate: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- License Type: string (nullable = true)
#  |-- Summons Number: integer (nullable = true)
#  |-- Issue Date: string (nullable = true)
#  |-- Violation Time: string (nullable = true)
#  |-- Violation: string (nullable = true)
#  |-- Judgment Entry Date: string (nullable = true)
#  |-- Fine Amount: double (nullable = true)
#  |-- Penalty Amount: double (nullable = true)
#  |-- Interest Amount: double (nullable = true)
#  |-- Reduction Amount: double (nullable = true)
#  |-- Payment Amount: double (nullable = true)
#  |-- Amount Due: double (nullable = true)
#  |-- Precinct: integer (nullable = true)
#  |-- County: string (nullable = true)
#  |-- Issuing Agency: string (nullable = true)
#  |-- Violation Status: string (nullable = true)
#  |-- Summons Image: string (nullable = true)

# %% [markdown]
# Now that we've explored the data, let's return to understanding
# **transformations** and **actions**.
# Let's create several transformations and then an action. After that we
# will inspect exactly what's happening under the hood.
#
# These transformations are simple, first we group by two variables and then compute the average fine.
# Then we're going to inner join that to the original dataset on the column State.
# Then we'll select the Violation Status from that new dataset.

# %%
# a simple grouping
df1 = fines.groupBy(["State","Violation"]).avg("Fine Amount") 

# a simple join and selecting some columns
df2 = df1 .join(fines, on=["Violation"], how='inner').select(["Plate","Violation","Violation Status"])

df1.show(10)
df2.show(10)
# Out:
# +-----+--------------------+----------------+
# |State|           Violation|avg(Fine Amount)|
# +-----+--------------------+----------------+
# |   NY|NO STOPPING-DAY/T...|           115.0|
# |   ME|NO PARKING-STREET...|            45.0|
# |   IN|        TRAFFIC LANE|           115.0|
# |   SC|  EXPIRED MUNI METER|            65.0|
# |   NJ|PHTO SCHOOL ZN SP...|            50.0|
# |   AZ|PHTO SCHOOL ZN SP...|            50.0|
# |   NY|FAIL TO DSPLY MUN...|            47.0|
# |   PA|NO STANDING-DAY/T...|           115.0|
# |   NY|OBSTRUCTING TRAFF...|           115.0|
# |   PA|STORAGE-3HR COMME...|            65.0|
# +-----+--------------------+----------------+
# only showing top 10 rows
#
# +-------+--------------------+-------------------+
# |  Plate|           Violation|   Violation Status|
# +-------+--------------------+-------------------+
# |1994439|    DETACHED TRAILER|    HEARING PENDING|
# |GJK1149|           CROSSWALK|               null|
# |GJK1149|           CROSSWALK|               null|
# |HXP4226|REG. STICKER-EXPI...|HEARING HELD-GUILTY|
# |1742308|    DETACHED TRAILER|    HEARING PENDING|
# | RR2L42|NO STANDING-DAY/T...|    HEARING PENDING|
# | RR2L42|NO STANDING-DAY/T...|    HEARING PENDING|
# | RR2L42|NO STANDING-DAY/T...|    HEARING PENDING|
# | RR2L42|NO STANDING-DAY/T...|    HEARING PENDING|
# |46886MM|NO PARKING-DAY/TI...|    HEARING PENDING|
# +-------+--------------------+-------------------+
# only showing top 10 rows

# %%
df2.explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [Plate#334, Violation#22, Violation Status#351]
#    +- BroadcastHashJoin [Violation#22], [Violation#340], Inner, BuildLeft, false
#       :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [id=#445]
#       :  +- HashAggregate(keys=[State#17, Violation#22], functions=[])
#       :     +- Exchange hashpartitioning(State#17, Violation#22, 200), ENSURE_REQUIREMENTS, [id=#442]
#       :        +- HashAggregate(keys=[State#17, Violation#22], functions=[])
#       :           +- Filter isnotnull(Violation#22)
#       :              +- FileScan csv [State#17,Violation#22] Batched: false, DataFilters: [isnotnull(Violation#22)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/jovyan/data/Open_Parking_and_Camera_Violations_100.csv], PartitionFilters: [], PushedFilters: [IsNotNull(Violation)], ReadSchema: struct<State:string,Violation:string>
#       +- Filter isnotnull(Violation#340)
#          +- FileScan csv [Plate#334,Violation#340,Violation Status#351] Batched: false, DataFilters: [isnotnull(Violation#340)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/jovyan/data/Open_Parking_and_Camera_Violations_100.csv], PartitionFilters: [], PushedFilters: [IsNotNull(Violation)], ReadSchema: struct<Plate:string,Violation:string,Violation Status:string>

# %%
# This will execute the plan that Apache Spark built up previously. 
df2.count()
# Out:
# 271

# %%
# we can convert to Pandas IF the data can fit into one node
df2.to_pandas_on_spark()
# Out:
# WARNING:root:'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
# 23/02/13 10:29:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 23/02/13 10:29:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 23/02/13 10:29:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 23/02/13 10:29:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#         Plate                       Violation               Violation Status
# 0     1994439                DETACHED TRAILER                HEARING PENDING
# 1     GJK1149                       CROSSWALK                           None
# 2     GJK1149                       CROSSWALK                           None
# 3     HXP4226    REG. STICKER-EXPIRED/MISSING            HEARING HELD-GUILTY
# 4     1742308                DETACHED TRAILER                HEARING PENDING
# 5      RR2L42     NO STANDING-DAY/TIME LIMITS                HEARING PENDING
# 6      RR2L42     NO STANDING-DAY/TIME LIMITS                HEARING PENDING
# 7      RR2L42     NO STANDING-DAY/TIME LIMITS                HEARING PENDING
# 8      RR2L42     NO STANDING-DAY/TIME LIMITS                HEARING PENDING
# 9     46886MM      NO PARKING-DAY/TIME LIMITS                HEARING PENDING
# 10    KVB7578     NO STANDING-DAY/TIME LIMITS            HEARING HELD-GUILTY
# 11    KVB7578     NO STANDING-DAY/TIME LIMITS            HEARING HELD-GUILTY
# 12    KVB7578     NO STANDING-DAY/TIME LIMITS            HEARING HELD-GUILTY
# 13    KVB7578     NO STANDING-DAY/TIME LIMITS            HEARING HELD-GUILTY
# 14    JCN1843     NO STANDING-DAY/TIME LIMITS                HEARING PENDING
# 15    JCN1843     NO STANDING-DAY/TIME LIMITS                HEARING PENDING
# 16    JCN1843     NO STANDING-DAY/TIME LIMITS                HEARING PENDING
# 17    JCN1843     NO STANDING-DAY/TIME LIMITS                HEARING PENDING
# 18    30599KA  FAIL TO DISP. MUNI METER RECPT                           None
# 19   T698300C       NO STANDING-HOTEL LOADING                           None
# 20   T672577C           NO PARKING-TAXI STAND                           None
# 21    91769KA    DOUBLE PARKING-MIDTOWN COMML            HEARING HELD-GUILTY
# 22    AC77860  FAIL TO DSPLY MUNI METER RECPT                           None
# 23    AC77860  FAIL TO DSPLY MUNI METER RECPT                           None
# 24    AC77860  FAIL TO DSPLY MUNI METER RECPT                           None
# 25    AC77860  FAIL TO DSPLY MUNI METER RECPT                           None
# 26    AC77860  FAIL TO DSPLY MUNI METER RECPT                           None
# 27     XCBF92     NO STANDING-DAY/TIME LIMITS                           None
# 28     XCBF92     NO STANDING-DAY/TIME LIMITS                           None
# 29     XCBF92     NO STANDING-DAY/TIME LIMITS                           None
# 30     XCBF92     NO STANDING-DAY/TIME LIMITS                           None
# 31    51463MM                  DOUBLE PARKING                           None
# 32    KEN5460  NO STANDING-EXC. AUTH. VEHICLE                           None
# 33    KDV4611     NO STANDING-DAY/TIME LIMITS                           None
# 34    KDV4611     NO STANDING-DAY/TIME LIMITS                           None
# 35    KDV4611     NO STANDING-DAY/TIME LIMITS                           None
# 36    KDV4611     NO STANDING-DAY/TIME LIMITS                           None
# 37    GFM1010                  DOUBLE PARKING                           None
# 38     U91GLT     NO STANDING-DAY/TIME LIMITS                           None
# 39     U91GLT     NO STANDING-DAY/TIME LIMITS                           None
# 40     U91GLT     NO STANDING-DAY/TIME LIMITS                           None
# 41     U91GLT     NO STANDING-DAY/TIME LIMITS                           None
# 42   T731981C   OBSTRUCTING TRAFFIC/INTERSECT                           None
# 43    JPZ7425                       CROSSWALK                           None
# 44    JPZ7425                       CROSSWALK                           None
# 45    JBK9036  FAIL TO DSPLY MUNI METER RECPT            HEARING ADJOURNMENT
# 46    JBK9036  FAIL TO DSPLY MUNI METER RECPT            HEARING ADJOURNMENT
# 47    JBK9036  FAIL TO DSPLY MUNI METER RECPT            HEARING ADJOURNMENT
# 48    JBK9036  FAIL TO DSPLY MUNI METER RECPT            HEARING ADJOURNMENT
# 49    JBK9036  FAIL TO DSPLY MUNI METER RECPT            HEARING ADJOURNMENT
# 50    KDF5110   INSP STICKER-MUTILATED/C'FEIT                           None
# 51    DZZ9072            OBSTRUCTING DRIVEWAY            HEARING HELD-GUILTY
# 52    2824372                DETACHED TRAILER                HEARING PENDING
# 53    HJV7825   INSP STICKER-MUTILATED/C'FEIT                           None
# 54    DER4535  FAIL TO DSPLY MUNI METER RECPT                           None
# 55    DER4535  FAIL TO DSPLY MUNI METER RECPT                           None
# 56    DER4535  FAIL TO DSPLY MUNI METER RECPT                           None
# 57    DER4535  FAIL TO DSPLY MUNI METER RECPT                           None
# 58    DER4535  FAIL TO DSPLY MUNI METER RECPT                           None
# 59    2824678                DETACHED TRAILER                HEARING PENDING
# 60    FGL8719     NO STANDING-DAY/TIME LIMITS                HEARING PENDING
# 61    FGL8719     NO STANDING-DAY/TIME LIMITS                HEARING PENDING
# 62    FGL8719     NO STANDING-DAY/TIME LIMITS                HEARING PENDING
# 63    FGL8719     NO STANDING-DAY/TIME LIMITS                HEARING PENDING
# 64     638380                    FIRE HYDRANT                           None
# 65     638380                    FIRE HYDRANT                           None
# 66     638380                    FIRE HYDRANT                           None
# 67     TTX42Y            NO STANDING-BUS STOP                           None
# 68    84079MK                    FIRE HYDRANT  HEARING HELD-GUILTY REDUCTION
# 69    84079MK                    FIRE HYDRANT  HEARING HELD-GUILTY REDUCTION
# 70    84079MK                    FIRE HYDRANT  HEARING HELD-GUILTY REDUCTION
# 71    GPW2531   INSP STICKER-MUTILATED/C'FEIT                           None
# 72    TY06688          STORAGE-3HR COMMERCIAL                HEARING PENDING
# 73    HTV5742                    FIRE HYDRANT                HEARING PENDING
# 74    HTV5742                    FIRE HYDRANT                HEARING PENDING
# 75    HTV5742                    FIRE HYDRANT                HEARING PENDING
# 76     7AVAE6     NO STANDING-COMM METER ZONE                           None
# 77     7AVAE6     NO STANDING-COMM METER ZONE                           None
# 78     7AVAE6     NO STANDING-COMM METER ZONE                           None
# 79    GJP9752              EXPIRED MUNI METER                           None
# 80    GJP9752              EXPIRED MUNI METER                           None
# 81     M94HMG  FAIL TO DSPLY MUNI METER RECPT  HEARING HELD-GUILTY REDUCTION
# 82     M94HMG  FAIL TO DSPLY MUNI METER RECPT  HEARING HELD-GUILTY REDUCTION
# 83     M94HMG  FAIL TO DSPLY MUNI METER RECPT  HEARING HELD-GUILTY REDUCTION
# 84     M94HMG  FAIL TO DSPLY MUNI METER RECPT  HEARING HELD-GUILTY REDUCTION
# 85     M94HMG  FAIL TO DSPLY MUNI METER RECPT  HEARING HELD-GUILTY REDUCTION
# 86    22463MK                       CROSSWALK                           None
# 87    22463MK                       CROSSWALK                           None
# 88     S72MYB  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 89     S72MYB  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 90     S72MYB  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 91     S72MYB  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 92     S72MYB  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 93    JFW7278  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 94    JFW7278  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 95    JFW7278  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 96    JFW7278  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 97    JFW7278  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 98    KLL4608      NO STANDING-SNOW EMERGENCY                           None
# 99    KLH4781      NO STANDING-SNOW EMERGENCY                           None
# 100   KKF7791              BUS LANE VIOLATION                           None
# 101   KKF7791              BUS LANE VIOLATION                           None
# 102   KKF7791              BUS LANE VIOLATION                           None
# 103   KKF7791              BUS LANE VIOLATION                           None
# 104   KKF7791              BUS LANE VIOLATION                           None
# 105    1844HY  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 106    1844HY  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 107    1844HY  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 108    1844HY  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 109    1844HY  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 110   GPK7470  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 111   GPK7470  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 112   GPK7470  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 113   GPK7470  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 114   GPK7470  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 115   49286KA                       BIKE LANE  HEARING HELD-GUILTY REDUCTION
# 116   42740JZ                    FIRE HYDRANT  HEARING HELD-GUILTY REDUCTION
# 117   42740JZ                    FIRE HYDRANT  HEARING HELD-GUILTY REDUCTION
# 118   42740JZ                    FIRE HYDRANT  HEARING HELD-GUILTY REDUCTION
# 119   2EC4169                       CROSSWALK                           None
# 120   2EC4169                       CROSSWALK                           None
# 121   JJJ6703   INSP. STICKER-EXPIRED/MISSING                           None
# 122   60137PC     NO STOPPING-DAY/TIME LIMITS            HEARING HELD-GUILTY
# 123   51126JU                  DOUBLE PARKING  HEARING HELD-GUILTY REDUCTION
# 124    M47KBG                    FIRE HYDRANT                           None
# 125    M47KBG                    FIRE HYDRANT                           None
# 126    M47KBG                    FIRE HYDRANT                           None
# 127   KEX4145              BUS LANE VIOLATION                           None
# 128   KEX4145              BUS LANE VIOLATION                           None
# 129   KEX4145              BUS LANE VIOLATION                           None
# 130   KEX4145              BUS LANE VIOLATION                           None
# 131   KEX4145              BUS LANE VIOLATION                           None
# 132   KLE1206              BUS LANE VIOLATION                           None
# 133   KLE1206              BUS LANE VIOLATION                           None
# 134   KLE1206              BUS LANE VIOLATION                           None
# 135   KLE1206              BUS LANE VIOLATION                           None
# 136   KLE1206              BUS LANE VIOLATION                           None
# 137   GCP7499      NO PARKING-STREET CLEANING                           None
# 138   GCP7499      NO PARKING-STREET CLEANING                           None
# 139   JSC4899      NO STANDING-SNOW EMERGENCY                           None
# 140   2824372      NO PARKING-STREET CLEANING                HEARING PENDING
# 141   2824372      NO PARKING-STREET CLEANING                HEARING PENDING
# 142    XEJH16    EXPIRED MUNI MTR-COMM MTR ZN                           None
# 143   2507629                    TRAFFIC LANE                HEARING PENDING
# 144   3BW6678  FAIL TO DSPLY MUNI METER RECPT                           None
# 145   3BW6678  FAIL TO DSPLY MUNI METER RECPT                           None
# 146   3BW6678  FAIL TO DSPLY MUNI METER RECPT                           None
# 147   3BW6678  FAIL TO DSPLY MUNI METER RECPT                           None
# 148   3BW6678  FAIL TO DSPLY MUNI METER RECPT                           None
# 149    NNS379              EXPIRED MUNI METER                           None
# 150    NNS379              EXPIRED MUNI METER                           None
# 151   18945TC    DOUBLE PARKING-MIDTOWN COMML            HEARING HELD-GUILTY
# 152   KBE6952     NO STANDING-COMM METER ZONE                           None
# 153   KBE6952     NO STANDING-COMM METER ZONE                           None
# 154   KBE6952     NO STANDING-COMM METER ZONE                           None
# 155   AD25928  FAIL TO DSPLY MUNI METER RECPT                           None
# 156   AD25928  FAIL TO DSPLY MUNI METER RECPT                           None
# 157   AD25928  FAIL TO DSPLY MUNI METER RECPT                           None
# 158   AD25928  FAIL TO DSPLY MUNI METER RECPT                           None
# 159   AD25928  FAIL TO DSPLY MUNI METER RECPT                           None
# 160   HHV5380  FAIL TO DSPLY MUNI METER RECPT                           None
# 161   HHV5380  FAIL TO DSPLY MUNI METER RECPT                           None
# 162   HHV5380  FAIL TO DSPLY MUNI METER RECPT                           None
# 163   HHV5380  FAIL TO DSPLY MUNI METER RECPT                           None
# 164   HHV5380  FAIL TO DSPLY MUNI METER RECPT                           None
# 165   AX30732                    FIRE HYDRANT                           None
# 166   AX30732                    FIRE HYDRANT                           None
# 167   AX30732                    FIRE HYDRANT                           None
# 168   HAY9541  FAIL TO DSPLY MUNI METER RECPT                           None
# 169   HAY9541  FAIL TO DSPLY MUNI METER RECPT                           None
# 170   HAY9541  FAIL TO DSPLY MUNI METER RECPT                           None
# 171   HAY9541  FAIL TO DSPLY MUNI METER RECPT                           None
# 172   HAY9541  FAIL TO DSPLY MUNI METER RECPT                           None
# 173   HHV5380   INSP. STICKER-EXPIRED/MISSING                           None
# 174   2DM7601  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 175   2DM7601  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 176   2DM7601  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 177   2DM7601  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 178   2DM7601  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 179   JCL3472  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 180   JCL3472  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 181   JCL3472  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 182   JCL3472  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 183   JCL3472  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 184    TUX21W              BUS LANE VIOLATION                           None
# 185    TUX21W              BUS LANE VIOLATION                           None
# 186    TUX21W              BUS LANE VIOLATION                           None
# 187    TUX21W              BUS LANE VIOLATION                           None
# 188    TUX21W              BUS LANE VIOLATION                           None
# 189   LKC8113              BUS LANE VIOLATION                           None
# 190   LKC8113              BUS LANE VIOLATION                           None
# 191   LKC8113              BUS LANE VIOLATION                           None
# 192   LKC8113              BUS LANE VIOLATION                           None
# 193   LKC8113              BUS LANE VIOLATION                           None
# 194   32456MM      NO STANDING-SNOW EMERGENCY                           None
# 195   JBH8668              EXPIRED MUNI METER        HEARING HELD-NOT GUILTY
# 196   JBH8668              EXPIRED MUNI METER        HEARING HELD-NOT GUILTY
# 197   58905MM                       CROSSWALK  HEARING HELD-GUILTY REDUCTION
# 198   58905MM                       CROSSWALK  HEARING HELD-GUILTY REDUCTION
# 199   KPX5913              BUS LANE VIOLATION                           None
# 200   KPX5913              BUS LANE VIOLATION                           None
# 201   KPX5913              BUS LANE VIOLATION                           None
# 202   KPX5913              BUS LANE VIOLATION                           None
# 203   KPX5913              BUS LANE VIOLATION                           None
# 204   2CN4270              BUS LANE VIOLATION                           None
# 205   2CN4270              BUS LANE VIOLATION                           None
# 206   2CN4270              BUS LANE VIOLATION                           None
# 207   2CN4270              BUS LANE VIOLATION                           None
# 208   2CN4270              BUS LANE VIOLATION                           None
# 209    E43MPW              BUS LANE VIOLATION                           None
# 210    E43MPW              BUS LANE VIOLATION                           None
# 211    E43MPW              BUS LANE VIOLATION                           None
# 212    E43MPW              BUS LANE VIOLATION                           None
# 213    E43MPW              BUS LANE VIOLATION                           None
# 214   HKM7046  NO STANDING-EXC. AUTH. VEHICLE                HEARING PENDING
# 215    V13HWK  FAIL TO DSPLY MUNI METER RECPT                           None
# 216    V13HWK  FAIL TO DSPLY MUNI METER RECPT                           None
# 217    V13HWK  FAIL TO DSPLY MUNI METER RECPT                           None
# 218    V13HWK  FAIL TO DSPLY MUNI METER RECPT                           None
# 219    V13HWK  FAIL TO DSPLY MUNI METER RECPT                           None
# 220   20324TC    DOUBLE PARKING-MIDTOWN COMML            HEARING HELD-GUILTY
# 221   71923ME    DOUBLE PARKING-MIDTOWN COMML            HEARING HELD-GUILTY
# 222   20332TC  FAIL TO DISP. MUNI METER RECPT            HEARING HELD-GUILTY
# 223   99822MB  FAIL TO DSPLY MUNI METER RECPT                           None
# 224   99822MB  FAIL TO DSPLY MUNI METER RECPT                           None
# 225   99822MB  FAIL TO DSPLY MUNI METER RECPT                           None
# 226   99822MB  FAIL TO DSPLY MUNI METER RECPT                           None
# 227   99822MB  FAIL TO DSPLY MUNI METER RECPT                           None
# 228   99822MB   PLTFRM LFTS LWRD POS COMM VEH                           None
# 229   HVN5087     NO STANDING-COMM METER ZONE                           None
# 230   HVN5087     NO STANDING-COMM METER ZONE                           None
# 231   HVN5087     NO STANDING-COMM METER ZONE                           None
# 232   HGD7023   OBSTRUCTING TRAFFIC/INTERSECT                           None
# 233    XCXA31     NO STANDING-DAY/TIME LIMITS                           None
# 234    XCXA31     NO STANDING-DAY/TIME LIMITS                           None
# 235    XCXA31     NO STANDING-DAY/TIME LIMITS                           None
# 236    XCXA31     NO STANDING-DAY/TIME LIMITS                           None
# 237    589AA1  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 238    589AA1  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 239    589AA1  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 240    589AA1  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 241    589AA1  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 242   AL50214  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 243   AL50214  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 244   AL50214  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 245   AL50214  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 246   AL50214  PHTO SCHOOL ZN SPEED VIOLATION                           None
# 247  T750180C              BUS LANE VIOLATION                           None
# 248  T750180C              BUS LANE VIOLATION                           None
# 249  T750180C              BUS LANE VIOLATION                           None
# 250  T750180C              BUS LANE VIOLATION                           None
# 251  T750180C              BUS LANE VIOLATION                           None
# 252  T794224C              BUS LANE VIOLATION                           None
# 253  T794224C              BUS LANE VIOLATION                           None
# 254  T794224C              BUS LANE VIOLATION                           None
# 255  T794224C              BUS LANE VIOLATION                           None
# 256  T794224C              BUS LANE VIOLATION                           None
# 257   31843MD              BUS LANE VIOLATION  HEARING HELD-GUILTY REDUCTION
# 258   31843MD              BUS LANE VIOLATION  HEARING HELD-GUILTY REDUCTION
# 259   31843MD              BUS LANE VIOLATION  HEARING HELD-GUILTY REDUCTION
# 260   31843MD              BUS LANE VIOLATION  HEARING HELD-GUILTY REDUCTION
# 261   31843MD              BUS LANE VIOLATION  HEARING HELD-GUILTY REDUCTION
# 262    3U40X0              BUS LANE VIOLATION                           None
# 263    3U40X0              BUS LANE VIOLATION                           None
# 264    3U40X0              BUS LANE VIOLATION                           None
# 265    3U40X0              BUS LANE VIOLATION                           None
# 266    3U40X0              BUS LANE VIOLATION                           None
# 267   JPY6971      NO STANDING-SNOW EMERGENCY                           None
# 268  T720744C  NO STANDING-EXC. AUTH. VEHICLE        HEARING HELD-NOT GUILTY
# 269   JKN9005                  DOUBLE PARKING                           None
# 270   53209PC      NO PARKING-DAY/TIME LIMITS        HEARING HELD-NOT GUILTY
